# %%
import numpy as np
import pandas as pd

# %%
# DATA FRAME DE LA SITUACIÓN DE LAS LENGUASE N EL MUNDO

df_lang = pd.read_csv("../data/languages.csv")

df_lang.info()

df_lang.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           2722 non-null   int64
#  1   Name in English              2722 non-null   object
#  2   Name in French               2699 non-null   object
#  3   Name in Spanish              2701 non-null   object
#  4   Countries                    2721 non-null   object
#  5   Country codes alpha 3        2721 non-null   object
#  6   ISO639-3 codes               2458 non-null   object
#  7   Degree of endangerment       2722 non-null   object
#  8   Alternate names              1583 non-null   object
#  9   Name in the language         27 non-null     object
#  10  Number of speakers           2539 non-null   float64
#  11  Sources                      2079 non-null   object
#  12  Latitude                     2719 non-null   float64
#  13  Longitude                    2719 non-null   float64
#  14  Description of the location  1870 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 319.1+ KB
#      ID              Name in English                    Name in French  \
# 0  1022                South Italian                    italien du sud
# 1  1023                     Sicilian                          sicilien
# 2   383                    Low Saxon                         bas-saxon
# 3   335                   Belarusian                        biélorusse
# 4   382                      Lombard                           lombard
# 5   405                       Romani                            romani
# 6  2211             Yiddish (Israel)                  yiddish (Israël)
# 7  1586                        Gondi                             gondi
# 8  1020         Limburgian-Ripuarian  francique ripuaire -limbourgeois
# 9  1943  Quechua of Southern Bolivia           quechua bolivien du sud
#
#                 Name in Spanish  \
# 0           napolitano-calabrés
# 1                     siciliano
# 2                    bajo sajón
# 3                    bielorruso
# 4                      lombardo
# 5                        romaní
# 6              yiddish (Israel)
# 7                         gondí
# 8          limburgués-ripuarino
# 9  quechua boliviano meridional
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# 9                   Bolivia (Plurinational State of)
#
#                                Country codes alpha 3  \
# 0                                                ITA
# 1                                                ITA
# 2                            DEU, DNK, NLD, POL, RUS
# 3                       BRB, LVA, LTU, POL, RUS, UKR
# 4                                           ITA, CHE
# 5  ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 6                                                ISR
# 7                                                IND
# 8                                      DEU, BEL, NLD
# 9                                                BOL
#
#                                      ISO639-3 codes Degree of endangerment  \
# 0                                               nap             Vulnerable
# 1                                               scn             Vulnerable
# 2  act, drt, frs, gos, nds, sdz, stl, twd, vel, wep             Vulnerable
# 3                                               bel             Vulnerable
# 4                                               lmo  Definitely endangered
# 5                 rmc, rmf, rml, rmn, rmo, rmw, rmy  Definitely endangered
# 6                                               ydd  Definitely endangered
# 7                                               gon             Vulnerable
# 8                                          ksh, lim             Vulnerable
# 9                                               quh             Vulnerable
#
#                                      Alternate names Name in the language  \
# 0  Neapolitan; Neapolitan-Calabrese; неаполитанск...                  NaN
# 1                                                NaN                  NaN
# 2  Low German, Niedersächsisch, Nedersaksisch, Ni...       Neddersassisch
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
# 5                                 sinti, vlax,  calò                  NaN
# 6                                       Judeo-German                  NaN
# 7  Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...                  NaN
# 8             Colognian (dialect; in German: Kölsch)                  NaN
# 9                                                NaN                  NaN
#
#    Number of speakers                                            Sources  \
# 0           7500000.0                                                NaN
# 1           5000000.0                                                NaN
# 2           4800000.0                                                NaN
# 3           4000000.0  Hienadź Cychun: Weißrussisch. — Lexikon der Sp...
# 4           3500000.0                                                NaN
# 5           3500000.0  Yaron Matras: Romani: a linguistic introductio...
# 6           3000000.0  Neil G. Jacobs: Yiddish: a linguistic introduc...
# 7           2713790.0                                                NaN
# 8           2600000.0                                                NaN
# 9           2300000.0                                                NaN
#
#    Latitude  Longitude                        Description of the location
# 0   40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1   37.4399    14.5019  Sicily (Sicilia), southern and central Calabri...
# 2   53.4029    10.3601  northern Germany, the north-eastern part of th...
# 3   53.9560    27.5756  Belarus except the Polesian-speaking south-wes...
# 4   45.7215     9.3273  the region of Lombardy (except the southernmos...
# 5   46.3165    22.3681  many European countries, most densely in East-...
# 6   32.0833    34.8333  most speakers now live outside Europe, mainly ...
# 7   19.5804    80.4418  Madhya Pradesh (Betul, Chhindwara, Seoni, Mand...
# 8   50.7781     6.0864  Limburg provinces in Belgium and the Netherlan...
# 9  -18.0675   -65.7641  Departments of Cochabamba, Chuquisaca, Potosí ...

# %% [markdown]
# ### 1. PREPARACIÓN DATASET LANGUAGES

# %% [markdown]
# - [ ] Eliminar columnas con nulo o bajo peso para nuestro análisis.
# - [ ] Categorizar la columna Degree of endangerment en una nueva columna.

# %%
# Eliminar columnas que poco peso o nulo que no vamos a utilizar en nuestro análisis
df_lang = df_lang.drop(['Name in French', 'Name in Spanish', 'Country codes alpha 3', 'ISO639-3 codes', 'Alternate names', 'Name in the language', 'Sources', 'Latitude', 'Longitude'], axis=1)

# %%
# normalizar el nombre de las columnas restantes
df_lang = df_lang.rename(columns={'Name in English': 'Name_English',
    'Degree of endangerment': 'Degree_endagerment',
    'Number of speakers': 'Number_speakers',
    'Description of the location': 'Description_location'
    }
)

# %%
# creación de una nueva columna con los valroes de endangerment order categorizada
endangerment_order = {
    'Vulnerable': 1,
    'Definitely endangered': 2,
    'Severely endangered': 3,
    'Critically endangered': 4,
    'Extinct': 5
}
df_lang['endangerment_score'] = df_lang['Degree_endagerment'].map(endangerment_order)

df_lang.head(20)
# Out:
#       ID                 Name_English  \
# 0   1022                South Italian
# 1   1023                     Sicilian
# 2    383                    Low Saxon
# 3    335                   Belarusian
# 4    382                      Lombard
# 5    405                       Romani
# 6   2211             Yiddish (Israel)
# 7   1586                        Gondi
# 8   1020         Limburgian-Ripuarian
# 9   1943  Quechua of Southern Bolivia
# 10  1565                      Kumaoni
# 11   755                       Aymara
# 12   349             Emilian-Romagnol
# 13   399                  Piedmontese
# 14  1021                      Venetan
# 15  1985                       Zazaki
# 16  1591                Kurux (India)
# 17  2065                      Tamajeq
# 18  1585                         Tulu
# 19  1556                       Kangdi
#
#                                             Countries     Degree_endagerment  \
# 0                                               Italy             Vulnerable
# 1                                               Italy             Vulnerable
# 2   Germany, Denmark, Netherlands, Poland, Russian...             Vulnerable
# 3   Belarus, Latvia, Lithuania, Poland, Russian Fe...             Vulnerable
# 4                                  Italy, Switzerland  Definitely endangered
# 5   Albania, Germany, Austria, Belarus, Bosnia and...  Definitely endangered
# 6                                              Israel  Definitely endangered
# 7                                               India             Vulnerable
# 8                       Germany, Belgium, Netherlands             Vulnerable
# 9                    Bolivia (Plurinational State of)             Vulnerable
# 10                                       India, Nepal             Vulnerable
# 11      Bolivia (Plurinational State of), Chile, Peru             Vulnerable
# 12                                  Italy, San Marino  Definitely endangered
# 13                                              Italy  Definitely endangered
# 14                           Croatia, Italy, Slovenia             Vulnerable
# 15                                             Turkey             Vulnerable
# 16                                              India             Vulnerable
# 17                                              Niger             Vulnerable
# 18                                              India             Vulnerable
# 19                                              India  Definitely endangered
#
#     Number_speakers                               Description_location  \
# 0         7500000.0  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1         5000000.0  Sicily (Sicilia), southern and central Calabri...
# 2         4800000.0  northern Germany, the north-eastern part of th...
# 3         4000000.0  Belarus except the Polesian-speaking south-wes...
# 4         3500000.0  the region of Lombardy (except the southernmos...
# 5         3500000.0  many European countries, most densely in East-...
# 6         3000000.0  most speakers now live outside Europe, mainly ...
# 7         2713790.0  Madhya Pradesh (Betul, Chhindwara, Seoni, Mand...
# 8         2600000.0  Limburg provinces in Belgium and the Netherlan...
# 9         2300000.0  Departments of Cochabamba, Chuquisaca, Potosí ...
# 10        2003783.0  Uttarakhand, also in Uttar Pradesh, Madhya Pra...
# 11        2000000.0  Departamentos  de Puno,  Moquegua y Tacna, en ...
# 12        2000000.0  the region of Emilia-Romagna, parts of the pro...
# 13        2000000.0  Piedmont Region except the Novara Province, th...
# 14        2000000.0  Veneto region, parts of Friuli-Venezia Giulia,...
# 15        2000000.0  Tunceli, Erzincan, Elazığ and Bingöl provinces...
# 16        1751489.0                                Jharkhand and Bihar
# 17        1750000.0                                                NaN
# 18        1722768.0                  Karnataka, Andhra Pradesh, Kerala
# 19        1700000.0                                   Himachal Pradesh
#
#     endangerment_score
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    2
# 5                    2
# 6                    2
# 7                    1
# 8                    1
# 9                    1
# 10                   1
# 11                   1
# 12                   2
# 13                   2
# 14                   1
# 15                   1
# 16                   1
# 17                   1
# 18                   1
# 19                   2

# %% [markdown]
# ### 2. PREPARACIÓN DATASET COUNTRIES

# %%
df_count = pd.read_csv("../data/countries of the world.csv")

df_count.info()

df_count.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
#  11  Arable (%)                          225 non-null    object
#  12  Crops (%)                           225 non-null    object
#  13  Other (%)                           225 non-null    object
#  14  Climate                             205 non-null    object
#  15  Birthrate                           224 non-null    object
#  16  Deathrate                           223 non-null    object
#  17  Agriculture                         212 non-null    object
#  18  Industry                            211 non-null    object
#  19  Service                             212 non-null    object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 35.6+ KB
#               Country                               Region  Population  \
# 0        Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1            Albania   EASTERN EUROPE                          3581655
# 2            Algeria   NORTHERN AFRICA                        32930091
# 3     American Samoa   OCEANIA                                   57794
# 4            Andorra   WESTERN EUROPE                            71201
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
# 5         1246700                        9,7                         0,13
# 6             102                      132,1                        59,80
# 7             443                      156,0                        34,54
# 8         2766890                       14,4                         0,18
# 9           29800                       99,9                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
# 5             0                             191,19              1900.0
# 6         10,76                              21,03              8600.0
# 7         -6,15                              19,46             11000.0
# 8          0,61                              15,18             11200.0
# 9         -6,47                              23,28              3500.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
# 5         42,0               7,8       2,41      0,24     97,35     NaN
# 6         95,0             460,0          0         0       100       2
# 7         89,0             549,9      18,18      4,55     77,27       2
# 8         97,1             220,4      12,31      0,48     87,21       3
# 9         98,6             195,7      17,55       2,3     80,15       4
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN
# 5     45,11      24,2       0,096    0,658   0,246
# 6     14,17      5,34        0,04     0,18    0,78
# 7     16,93      5,37       0,038     0,22   0,743
# 8     16,73      7,55       0,095    0,358   0,547
# 9     12,07      8,23       0,239    0,343   0,418

# %% [markdown]
# #### 2.1 Limpieza de formato de datos y columnas
# - [ ] Eliminar espacios en blanco en nombres de columnas. Estandarizar nombres a formato snake_case.
# - [ ] Comprobar si los separadores decimales están en formato correcto (algunas versiones usan coma en vez de punto).
# - [ ] Conversión de tipos
# - [ ] Convertir a `category`:
#   - Country
#   - Region
#   - Climate (variable categórica codificada)

# %%
# Normalización de los nombres de las columnas
df_count = df_count.rename(columns={'Area (sq. mi.)': 'Area_sq_mi',
    'Pop. Density (per sq. mi.)': 'Pop_density',
    'Coastline (coast/area ratio)': 'Coastline',
    'Net migration': 'Migration',
    'Infant mortality (per 1000 births)': 'Infant_mortality',
    'GDP ($ per capita)': 'GDP',
    'Literacy (%)': 'Literacy',
    'Phones (per 1000)': 'Phones',
    'Arable (%)': 'Arable',
    'Crops (%)': 'Crops',
    'Other (%)': 'Other'
    }
)

# %%
def search_cols_with_commas(df):
    cols = []
    for col in df.columns:
        if df[col].dtype == 'object' and df[col].str.contains(',', regex=False, na=False).any():
            cols.append(col)
    return cols

cols_with_commas = search_cols_with_commas(df_count)
print(cols_with_commas)
# Out:
# ['Country', 'Pop_density', 'Coastline', 'Migration', 'Infant_mortality', 'Literacy', 'Phones', 'Arable', 'Crops', 'Other', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service']

# %%
del cols_with_commas[0] # Eliminamos la columan Country porque realmente es string
print(cols_with_commas)
# Out:
# ['Pop_density', 'Coastline', 'Migration', 'Infant_mortality', 'Literacy', 'Phones', 'Arable', 'Crops', 'Other', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service']

# %%
# Convertir los valores numéricos de string a float
for col in cols_with_commas:
    df_count[col] = (
        df_count[col]
        .str.replace(',', '.', regex=False)
        .astype(float)
    )

# %% [markdown]
# Para optimizar operaciones como groupby, value_counts.
# Evitar errores al no permitir texto libre.
# Especificar que no tienen carácter numérico
# - [ ] Convertir a `category` :
#   - Country
#   - Region
#   - Climate (variable categórica codificada)

# %%
df_count["Country"] = df_count["Country"].astype("category")
df_count["Region"] = df_count["Region"].astype("category")
# para categorizar la columna clima nos quedaremos con el primer valor ya que no es un factor con suficiente peso en nuestro EDA
df_count["Climate"] = (
    df_count["Climate"]
    .astype(str)
    .str.split(",", n=1)
    .str[0]
    .str.strip()
    .replace({"nan": None})
    .astype("category")
)
df_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           227 non-null    category
#  1   Region            227 non-null    category
#  2   Population        227 non-null    int64
#  3   Area_sq_mi        227 non-null    int64
#  4   Pop_density       227 non-null    float64
#  5   Coastline         227 non-null    float64
#  6   Migration         224 non-null    float64
#  7   Infant_mortality  224 non-null    float64
#  8   GDP               226 non-null    float64
#  9   Literacy          209 non-null    float64
#  10  Phones            223 non-null    float64
#  11  Arable            225 non-null    float64
#  12  Crops             225 non-null    float64
#  13  Other             225 non-null    float64
#  14  Climate           205 non-null    category
#  15  Birthrate         224 non-null    float64
#  16  Deathrate         223 non-null    float64
#  17  Agriculture       212 non-null    float64
#  18  Industry          211 non-null    float64
#  19  Service           212 non-null    float64
# dtypes: category(3), float64(15), int64(2)
# memory usage: 41.6 KB

# %% [markdown]
# #### 2.2 Limpieza de formato de datos y columnas
# - [ ] Identificar columnas con `NaN`.
# - [ ] Decidir estrategia:
#   - Imputación (media/mediana) para variables numéricas.
#   - Imputación por moda para categóricas.
#   - Eliminación de filas si el porcentaje de nulos es bajo.
# - [ ] Documentar la decisión (importante para reproducibilidad).

# %%
# Identificar columans con NaN
cols_con_nulos = df_count.columns[df_count.isna().any()]
cols_con_nulos
# Out:
# Index(['Migration', 'Infant_mortality', 'GDP', 'Literacy', 'Phones', 'Arable',
#        'Crops', 'Other', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service'],
#       dtype='object')

# %%
def replace_nan_by_mean(df, columns, group_col="Region"):
    for col in columns:
        # Sólo reemplazar si la columna es numérica
        if df[col].dtype.kind in "fi":  # float o int
            df[col] = df[col].fillna(
                df.groupby(group_col)[col].transform("mean")
            )
    return df

# %%
df_cof_treated = replace_nan_by_mean(df_count, cols_con_nulos)

df_cof_treated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           227 non-null    category
#  1   Region            227 non-null    category
#  2   Population        227 non-null    int64
#  3   Area_sq_mi        227 non-null    int64
#  4   Pop_density       227 non-null    float64
#  5   Coastline         227 non-null    float64
#  6   Migration         227 non-null    float64
#  7   Infant_mortality  227 non-null    float64
#  8   GDP               227 non-null    float64
#  9   Literacy          227 non-null    float64
#  10  Phones            227 non-null    float64
#  11  Arable            227 non-null    float64
#  12  Crops             227 non-null    float64
#  13  Other             227 non-null    float64
#  14  Climate           205 non-null    category
#  15  Birthrate         227 non-null    float64
#  16  Deathrate         227 non-null    float64
#  17  Agriculture       227 non-null    float64
#  18  Industry          227 non-null    float64
#  19  Service           227 non-null    float64
# dtypes: category(3), float64(15), int64(2)
# memory usage: 41.6 KB
# C:\Users\m_fon\AppData\Local\Temp\ipykernel_15552\596111315.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(group_col)[col].transform("mean")
